# %%
tags_list = ['begin-end-xml', 'begin-kml', 'begin-Document', 'begin-name', 'end-name', 'begin-open',
             'end-open', 'begin-description', 'end-description', 'begin-Style', 'begin-IconStyle', 'begin-Icon',
             'begin-href', 'end-href', 'end-Icon', 'end-IconStyle', 'end-Style', 'begin-Style',
             'begin-IconStyle', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'end-IconStyle',
             'begin-LineStyle', 'begin-width', 'end-width', 'end-LineStyle', 'end-Style', 'begin-Style',
             'begin-LineStyle', 'begin-color', 'end-color', 'begin-width', 'end-width', 'end-LineStyle',
             'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style',
             'begin-LineStyle', 'begin-color', 'end-color', 'begin-width', 'end-width', 'end-LineStyle',
             'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style',
             'begin-LineStyle', 'begin-color', 'end-color', 'begin-width', 'end-width', 'end-LineStyle',
             'end-Style', 'begin-Style', 'begin-LineStyle', 'begin-color', 'end-color', 'end-LineStyle',
             'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style',
             'begin-LineStyle', 'begin-color', 'end-color', 'end-LineStyle', 'begin-PolyStyle', 'begin-color',
             'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style', 'begin-LineStyle', 'begin-width',
             'end-width', 'end-LineStyle', 'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle',
             'end-Style', 'begin-Style', 'begin-LineStyle', 'begin-width', 'end-width', 'end-LineStyle',
             'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style',
             'begin-LineStyle', 'begin-width', 'end-width', 'end-LineStyle', 'begin-PolyStyle', 'begin-color',
             'end-color', 'end-PolyStyle', 'end-Style', 'begin-Style', 'begin-LineStyle', 'begin-width',
             'end-width', 'end-LineStyle', 'begin-PolyStyle', 'begin-color', 'end-color', 'end-PolyStyle',
             'end-Style', 'begin-Style', 'begin-BalloonStyle', 'begin-text', 'end-text', 'end-BalloonStyle',
             'end-Style', 'begin-Folder', 'begin-name', 'end-name', 'begin-description', 'end-description',
             'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude', 'end-latitude',
             'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt',
             'begin-range', 'end-range', 'end-LookAt', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-description', 'end-description', 'begin-Point', 'begin-coordinates', 'end-coordinates',
             'end-Point', 'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude',
             'end-longitude', 'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-styleUrl', 'end-styleUrl', 'begin-Point', 'begin-altitudeMode', 'end-altitudeMode',
             'begin-coordinates', 'end-coordinates', 'end-Point', 'end-Placemark', 'begin-Placemark',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-description',
             'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude',
             'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt',
             'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl', 'end-styleUrl',
             'begin-Point', 'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode',
             'begin-coordinates', 'end-coordinates', 'end-Point', 'end-Placemark', 'end-Folder', 'begin-Folder',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-description',
             'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude',
             'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt',
             'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl', 'end-styleUrl',
             'begin-Document', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude',
             'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading',
             'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-Style',
             'begin-IconStyle', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'end-IconStyle',
             'end-Style', 'begin-Style', 'begin-IconStyle', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon',
             'end-IconStyle', 'end-Style', 'begin-StyleMap', 'begin-Pair', 'begin-key', 'end-key',
             'begin-styleUrl', 'end-styleUrl', 'end-Pair', 'begin-Pair', 'begin-key', 'end-key',
             'begin-styleUrl', 'end-styleUrl', 'end-Pair', 'end-StyleMap', 'begin-Placemark', 'begin-name',
             'end-name', 'begin-visibility', 'end-visibility', 'begin-styleUrl', 'end-styleUrl', 'begin-Point',
             'begin-coordinates', 'end-coordinates', 'end-Point', 'end-Placemark', 'end-Document',
             'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'end-Placemark', 'end-Folder', 'begin-Folder',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-description',
             'end-description', 'begin-GroundOverlay', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude',
             'end-longitude', 'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'begin-LatLonBox', 'begin-north', 'end-north',
             'begin-south', 'end-south', 'begin-east', 'end-east', 'begin-west', 'end-west', 'begin-rotation',
             'end-rotation', 'end-LatLonBox', 'end-GroundOverlay', 'end-Folder', 'begin-Folder', 'begin-name',
             'end-name', 'begin-visibility', 'end-visibility', 'begin-description', 'end-description',
             'begin-ScreenOverlay', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon',
             'begin-end-overlayXY', 'begin-end-screenXY', 'begin-end-rotationXY', 'begin-end-size',
             'end-ScreenOverlay', 'begin-ScreenOverlay', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'begin-end-overlayXY',
             'begin-end-screenXY', 'begin-end-rotationXY', 'begin-end-size', 'end-ScreenOverlay',
             'begin-ScreenOverlay', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'begin-end-overlayXY', 'begin-end-screenXY',
             'begin-end-rotationXY', 'begin-end-size', 'end-ScreenOverlay', 'begin-ScreenOverlay', 'begin-name',
             'end-name', 'begin-visibility', 'end-visibility', 'begin-Icon', 'begin-href', 'end-href',
             'end-Icon', 'begin-end-overlayXY', 'begin-end-screenXY', 'begin-end-rotationXY', 'begin-end-size',
             'end-ScreenOverlay', 'begin-ScreenOverlay', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'begin-end-overlayXY',
             'begin-end-screenXY', 'begin-end-rotationXY', 'begin-end-size', 'end-ScreenOverlay',
             'begin-ScreenOverlay', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-Icon', 'begin-href', 'end-href', 'end-Icon', 'begin-end-overlayXY', 'begin-end-screenXY',
             'begin-end-rotationXY', 'begin-end-size', 'end-ScreenOverlay', 'begin-ScreenOverlay', 'begin-name',
             'end-name', 'begin-visibility', 'end-visibility', 'begin-Icon', 'begin-href', 'end-href',
             'end-Icon', 'begin-end-overlayXY', 'begin-end-screenXY', 'begin-end-rotationXY', 'begin-end-size',
             'end-ScreenOverlay', 'end-Folder', 'begin-Folder', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-description', 'end-description', 'begin-Placemark', 'begin-name',
             'end-name', 'begin-visibility', 'end-visibility', 'begin-description', 'end-description',
             'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude', 'end-latitude',
             'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt',
             'begin-range', 'end-range', 'end-LookAt', 'begin-LineString', 'begin-tessellate', 'end-tessellate',
             'begin-coordinates', 'end-coordinates', 'end-LineString', 'end-Placemark', 'begin-Placemark',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-description',
             'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude',
             'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt',
             'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-LineString', 'begin-tessellate',
             'end-tessellate', 'begin-coordinates', 'end-coordinates', 'end-LineString', 'end-Placemark',
             'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude',
             'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading',
             'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl',
             'end-styleUrl', 'begin-LineString', 'begin-tessellate', 'end-tessellate', 'begin-altitudeMode',
             'end-altitudeMode', 'begin-coordinates', 'end-coordinates', 'end-LineString', 'end-Placemark',
             'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude',
             'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading',
             'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl',
             'end-styleUrl', 'begin-LineString', 'begin-extrude', 'end-extrude', 'begin-tessellate',
             'end-tessellate', 'begin-altitudeMode', 'end-altitudeMode', 'begin-coordinates', 'end-coordinates',
             'end-LineString', 'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude',
             'end-longitude', 'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-styleUrl', 'end-styleUrl', 'begin-LineString', 'begin-tessellate', 'end-tessellate',
             'begin-altitudeMode', 'end-altitudeMode', 'begin-coordinates', 'end-coordinates', 'end-LineString',
             'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude',
             'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading',
             'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl',
             'end-styleUrl', 'begin-LineString', 'begin-extrude', 'end-extrude', 'begin-tessellate',
             'end-tessellate', 'begin-altitudeMode', 'end-altitudeMode', 'begin-coordinates', 'end-coordinates',
             'end-LineString', 'end-Placemark', 'end-Folder', 'begin-Folder', 'begin-name', 'end-name',
             'begin-visibility', 'end-visibility', 'begin-description', 'end-description', 'begin-Folder',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-description',
             'end-description', 'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude',
             'end-latitude', 'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt',
             'end-tilt', 'begin-range', 'end-range', 'end-LookAt', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-visibility', 'end-visibility', 'begin-styleUrl', 'end-styleUrl', 'begin-Polygon',
             'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs',
             'begin-LinearRing', 'begin-coordinates', 'end-coordinates', 'end-LinearRing',
             'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-visibility', 'end-visibility', 'begin-styleUrl', 'end-styleUrl', 'begin-Polygon',
             'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs',
             'begin-LinearRing', 'begin-coordinates', 'end-coordinates', 'end-LinearRing',
             'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-visibility', 'end-visibility', 'begin-styleUrl', 'end-styleUrl', 'begin-Polygon',
             'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs',
             'begin-LinearRing', 'begin-coordinates', 'end-coordinates', 'end-LinearRing',
             'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-visibility', 'end-visibility', 'begin-styleUrl', 'end-styleUrl', 'begin-Polygon',
             'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs',
             'begin-LinearRing', 'begin-coordinates', 'end-coordinates', 'end-LinearRing',
             'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark', 'end-Folder', 'begin-Folder', 'begin-name',
             'end-name', 'begin-description', 'end-description', 'begin-Placemark', 'begin-name', 'end-name',
             'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude', 'end-latitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-Polygon', 'begin-extrude', 'end-extrude', 'begin-altitudeMode', 'end-altitudeMode',
             'begin-outerBoundaryIs', 'begin-LinearRing', 'begin-coordinates', 'end-coordinates',
             'end-LinearRing', 'end-outerBoundaryIs', 'begin-innerBoundaryIs', 'begin-LinearRing',
             'begin-coordinates', 'end-coordinates', 'end-LinearRing', 'end-innerBoundaryIs', 'end-Polygon',
             'end-Placemark', 'end-Folder', 'begin-Folder', 'begin-name', 'end-name', 'begin-visibility',
             'end-visibility', 'begin-description', 'end-description', 'begin-LookAt', 'begin-longitude',
             'end-longitude', 'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-styleUrl', 'end-styleUrl', 'begin-Polygon', 'begin-tessellate', 'end-tessellate',
             'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs', 'begin-LinearRing',
             'begin-coordinates', 'end-coordinates', 'end-LinearRing', 'end-outerBoundaryIs', 'end-Polygon',
             'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-styleUrl', 'end-styleUrl', 'begin-Polygon', 'begin-extrude', 'end-extrude',
             'begin-tessellate', 'end-tessellate', 'begin-altitudeMode', 'end-altitudeMode',
             'begin-outerBoundaryIs', 'begin-LinearRing', 'begin-coordinates', 'end-coordinates',
             'end-LinearRing', 'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark', 'begin-Placemark',
             'begin-name', 'end-name', 'begin-visibility', 'end-visibility', 'begin-LookAt', 'begin-longitude',
             'end-longitude', 'begin-latitude', 'end-latitude', 'begin-altitude', 'end-altitude',
             'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt', 'begin-range', 'end-range', 'end-LookAt',
             'begin-styleUrl', 'end-styleUrl', 'begin-Polygon', 'begin-tessellate', 'end-tessellate',
             'begin-altitudeMode', 'end-altitudeMode', 'begin-outerBoundaryIs', 'begin-LinearRing',
             'begin-coordinates', 'end-coordinates', 'end-LinearRing', 'end-outerBoundaryIs', 'end-Polygon',
             'end-Placemark', 'begin-Placemark', 'begin-name', 'end-name', 'begin-visibility', 'end-visibility',
             'begin-LookAt', 'begin-longitude', 'end-longitude', 'begin-latitude', 'end-latitude',
             'begin-altitude', 'end-altitude', 'begin-heading', 'end-heading', 'begin-tilt', 'end-tilt',
             'begin-range', 'end-range', 'end-LookAt', 'begin-styleUrl', 'end-styleUrl', 'begin-Polygon',
             'begin-extrude', 'end-extrude', 'begin-tessellate', 'end-tessellate', 'begin-altitudeMode',
             'end-altitudeMode', 'begin-outerBoundaryIs', 'begin-LinearRing', 'begin-coordinates',
             'end-coordinates', 'end-LinearRing', 'end-outerBoundaryIs', 'end-Polygon', 'end-Placemark',
             'end-Folder', 'end-Folder', 'end-Document', 'end-kml']

# %%
def index(subseq, seq):
    """Return an index of `subseq`uence in the `seq`uence.

    Or `-1` if `subseq` is not a subsequence of the `seq`.

    The time complexity of the algorithm is O(n*m), where

        n, m = len(seq), len(subseq)

    >>> index([1,2], range(5))
    1
    >>> index(range(1, 6), range(5))
    -1
    >>> index(range(5), range(5))
    0
    >>> index([1,2], [0, 1, 0, 1, 2])
    3
    """
    i, n, m = -1, len(seq), len(subseq)
    try:
        while True:
            i = seq.index(subseq[0], i + 1, n - m + 1)
            if subseq == seq[i:i + m]:
               return i
    except ValueError:
        return -1

# %%
sequence_dict = {}
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        sequence_dict['{}_{}'.format(tag1, tag2)] = 0
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        for n in range(2, len(tags_list)+1):
            if [tag1, tag2] == tags_list[n-2:n]:
                sequence_dict['{}_{}'.format(tag1, tag2)] = sequence_dict['{}_{}'.format(tag1, tag2)] + 1

# %%
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        for tag3 in set(tags_list):
            seq_list = [tag1, tag2, tag3]
            sequence_dict['{}_{}_{}'.format(*seq_list)] = 0
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        for tag3 in set(tags_list):
            seq_list = [tag1, tag2, tag3]
            for n in range(3, len(tags_list)+1):
                if seq_list == tags_list[n-3:n]:
                    seq_str = '{}_{}_{}'.format(*seq_list)
                    sequence_dict[seq_str] = sequence_dict[seq_str] + 1

# %%
sorted(sequence_dict.items(), key=lambda kv: kv[1], reverse=True)[:10]
# Out:
# [('begin-name_end-name', 39),
#  ('begin-visibility_end-visibility', 34),
#  ('end-name_begin-visibility', 34),
#  ('begin-name_end-name_begin-visibility', 34),
#  ('end-name_begin-visibility_end-visibility', 34),
#  ('begin-description_end-description', 23),
#  ('begin-coordinates_end-coordinates', 20),
#  ('begin-Placemark_begin-name', 20),
#  ('begin-Placemark_begin-name_end-name', 20),
#  ('end-visibility_begin-description', 19)]

# %%
four_sequence_dict = {}
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        for tag3 in set(tags_list):
            for tag4 in set(tags_list):
                seq_list = [tag1, tag2, tag3, tag4]
                seq_str = '{}_{}_{}_{}'.format(*seq_list)
                four_sequence_dict[seq_str] = 0
for tag1 in set(tags_list):
    for tag2 in set(tags_list):
        for tag3 in set(tags_list):
            for tag4 in set(tags_list):
                seq_list = [tag1, tag2, tag3, tag4]
                seq_str = '{}_{}_{}_{}'.format(*seq_list)
                for n in range(len(seq_list), len(tags_list)+1):
                    if seq_list == tags_list[n-len(seq_list):n]:
                        four_sequence_dict[seq_str] = four_sequence_dict[seq_str] + 1

# %%
sorted(four_sequence_dict.items(), key=lambda kv: kv[1], reverse=True)[:10]
