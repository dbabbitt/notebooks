# %%
import random

class Group:
    def __init__(self, name, pos_ethno, neg_ethno):
        self.name = name
        self.pos_ethno = pos_ethno  # Positive ethnocentrism (in-group favoritism)
        self.neg_ethno = neg_ethno  # Negative ethnocentrism (out-group hostility)
        self.members = []

    def add_member(self, member):
        self.members.append(member)

    def is_empty(self):
        return len(self.members) == 0

class Individual:
    def __init__(self, group):
        self.group = group
        self.resources = 100  # Starting resources

def initialize_population(group_configs, population_size):
    groups = [Group(name, pos, neg) for name, pos, neg in group_configs]
    population = []
    for _ in range(population_size):
        group = random.choice(groups)
        individual = Individual(group)
        group.add_member(individual)
        population.append(individual)
    return population, groups

def interact(individual1, individual2):
    same_group = individual1.group == individual2.group
    
    if same_group:
        cooperation_chance = individual1.group.pos_ethno
    else:
        cooperation_chance = 1 - individual1.group.neg_ethno
    
    # Cooperation: both gain resources
    if random.random() < cooperation_chance:
        individual1.resources += 10
        individual2.resources += 10
    
    # Conflict: one gains, one loses
    else:
        if random.random() < 0.5:
            individual1.resources += 20
            individual2.resources -= 10
        else:
            individual1.resources -= 10
            individual2.resources += 20

def run_simulation(population, num_interactions):
    for _ in range(num_interactions):
        ind1, ind2 = random.sample(population, 2)
        interact(ind1, ind2)

def analyze_results(groups):
    for group in groups:
        if group.is_empty():
            print(f"{group.name}: No members")
        else:
            avg_resources = sum(m.resources for m in group.members) / len(group.members)
            print(f"{group.name}: Average resources = {avg_resources:.2f}")

# Set up and run simulation
group_configs = []
for pos_ethno in range(0, 11, 1):
    for neg_ethno in range(0, 11, 1):
        group_tuple = (f'Group {pos_ethno:02}{neg_ethno:02}', pos_ethno/10, neg_ethno/10)
        group_configs.append(group_tuple)

population, groups = initialize_population(group_configs, population_size=300)
run_simulation(population, num_interactions=10000)
analyze_results(groups)
# Out:
# Group 0000: Average resources = 710.00
# Group 0001: Average resources = 693.33
# Group 0002: Average resources = 686.00
# Group 0003: Average resources = 600.00
# Group 0004: Average resources = 647.50
# Group 0005: Average resources = 528.00
# Group 0006: Average resources = 610.00
# Group 0007: Average resources = 550.00
# Group 0008: Average resources = 680.00
# Group 0009: Average resources = 490.00
# Group 0010: Average resources = 505.00
# Group 0100: Average resources = 650.00
# Group 0101: Average resources = 693.33
# Group 0102: Average resources = 760.00
# Group 0103: Average resources = 660.00
# Group 0104: Average resources = 593.33
# Group 0105: Average resources = 560.00
# Group 0106: Average resources = 492.00
# Group 0107: Average resources = 600.00
# Group 0108: Average resources = 515.00
# Group 0109: Average resources = 620.00
# Group 0110: Average resources = 440.00
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 68
#      66 population, groups = initialize_population(group_configs, population_size=300)
#      67 run_simulation(population, num_interactions=10000)
# ---> 68 analyze_results(groups)
#
# Cell In[8], line 56, in analyze_results(groups)
#      54 def analyze_results(groups):
#      55     for group in groups:
# ---> 56         avg_resources = sum(m.resources for m in group.members) / len(group.members)
#      57         print(f"{group.name}: Average resources = {avg_resources:.2f}")
#
# ZeroDivisionError: division by zero

# %%
[group.members for group in groups]
# Out:
# [[<__main__.Individual at 0x2ccdf720310>,
#   <__main__.Individual at 0x2cce00e6070>],
#  [<__main__.Individual at 0x2cce00e5370>,
#   <__main__.Individual at 0x2cce00d3310>,
#   <__main__.Individual at 0x2cce00cf550>],
#  [<__main__.Individual at 0x2ccde6537f0>,
#   <__main__.Individual at 0x2ccdf70cca0>,
#   <__main__.Individual at 0x2cce00e64f0>,
#   <__main__.Individual at 0x2cce00d3eb0>,
#   <__main__.Individual at 0x2cce00cf190>],
#  [<__main__.Individual at 0x2ccde653ca0>,
#   <__main__.Individual at 0x2ccde6a4190>,
#   <__main__.Individual at 0x2cce00e5070>],
#  [<__main__.Individual at 0x2ccde4e55b0>,
#   <__main__.Individual at 0x2cce00e66d0>,
#   <__main__.Individual at 0x2cce00d33d0>,
#   <__main__.Individual at 0x2cce00d3550>],
#  [<__main__.Individual at 0x2ccde68f2e0>,
#   <__main__.Individual at 0x2cce00e6f70>,
#   <__main__.Individual at 0x2cce00e5610>,
#   <__main__.Individual at 0x2cce00d3d30>,
#   <__main__.Individual at 0x2cce00d3f10>],
#  [<__main__.Individual at 0x2ccde68f490>,
#   <__main__.Individual at 0x2ccde69f2b0>],
#  [<__main__.Individual at 0x2ccdf70cd60>,
#   <__main__.Individual at 0x2ccdf7200d0>,
#   <__main__.Individual at 0x2cce00e63d0>,
#   <__main__.Individual at 0x2cce00e6b50>],
#  [<__main__.Individual at 0x2ccdf8a1040>],
#  [<__main__.Individual at 0x2ccdf70c070>,
#   <__main__.Individual at 0x2ccdf70cdc0>],
#  [<__main__.Individual at 0x2ccdf70c9a0>,
#   <__main__.Individual at 0x2cce00d32b0>],
#  [<__main__.Individual at 0x2ccdf70c820>,
#   <__main__.Individual at 0x2cce00d3f70>],
#  [<__main__.Individual at 0x2ccdf6e1b20>,
#   <__main__.Individual at 0x2ccdf70cc40>,
#   <__main__.Individual at 0x2cce00d3730>],
#  [<__main__.Individual at 0x2ccde69f340>],
#  [<__main__.Individual at 0x2ccde653850>,
#   <__main__.Individual at 0x2ccde4e5490>,
#   <__main__.Individual at 0x2ccde69fe80>,
#   <__main__.Individual at 0x2cce00e6730>,
#   <__main__.Individual at 0x2cce00e5910>],
#  [<__main__.Individual at 0x2ccde653a90>,
#   <__main__.Individual at 0x2cce00d3b50>,
#   <__main__.Individual at 0x2cce00cf4f0>],
#  [<__main__.Individual at 0x2ccdf8093a0>,
#   <__main__.Individual at 0x2ccdf70c310>,
#   <__main__.Individual at 0x2cce00e61f0>],
#  [<__main__.Individual at 0x2ccdf720130>,
#   <__main__.Individual at 0x2ccdf8a1f10>,
#   <__main__.Individual at 0x2cce00e6190>,
#   <__main__.Individual at 0x2cce00e6610>,
#   <__main__.Individual at 0x2cce00cf250>],
#  [<__main__.Individual at 0x2ccdf8090d0>,
#   <__main__.Individual at 0x2ccdf809910>,
#   <__main__.Individual at 0x2ccdf8a1c70>,
#   <__main__.Individual at 0x2cce00d3670>],
#  [<__main__.Individual at 0x2ccde4e50d0>,
#   <__main__.Individual at 0x2ccde689340>],
#  [<__main__.Individual at 0x2ccdf82fe20>],
#  [<__main__.Individual at 0x2ccdf70cee0>,
#   <__main__.Individual at 0x2cce00e6430>],
#  [],
#  [<__main__.Individual at 0x2ccde653580>,
#   <__main__.Individual at 0x2ccdf87abb0>,
#   <__main__.Individual at 0x2cce00e5b50>,
#   <__main__.Individual at 0x2cce00d3d90>],
#  [<__main__.Individual at 0x2ccde653100>,
#   <__main__.Individual at 0x2ccde50a850>,
#   <__main__.Individual at 0x2cce00e56d0>,
#   <__main__.Individual at 0x2cce00d3130>],
#  [<__main__.Individual at 0x2cce00cf3d0>],
#  [<__main__.Individual at 0x2cce00e5670>],
#  [<__main__.Individual at 0x2ccdf7202b0>,
#   <__main__.Individual at 0x2cce00e5130>,
#   <__main__.Individual at 0x2cce00cf490>],
#  [<__main__.Individual at 0x2cce00cf2b0>],
#  [<__main__.Individual at 0x2ccdf8a1fd0>,
#   <__main__.Individual at 0x2cce00e5fd0>,
#   <__main__.Individual at 0x2cce00d3070>],
#  [<__main__.Individual at 0x2ccdf70c670>,
#   <__main__.Individual at 0x2ccdf70c7c0>,
#   <__main__.Individual at 0x2cce00e6130>,
#   <__main__.Individual at 0x2cce00cf0d0>],
#  [],
#  [<__main__.Individual at 0x2cce00e6a90>,
#   <__main__.Individual at 0x2cce00cf130>],
#  [<__main__.Individual at 0x2ccde4e5190>,
#   <__main__.Individual at 0x2ccdf70c430>,
#   <__main__.Individual at 0x2cce00e6490>,
#   <__main__.Individual at 0x2cce00e5c70>,
#   <__main__.Individual at 0x2cce00d38b0>],
#  [<__main__.Individual at 0x2cce00e6eb0>],
#  [<__main__.Individual at 0x2ccde089cd0>,
#   <__main__.Individual at 0x2ccdf720070>],
#  [<__main__.Individual at 0x2ccde653a00>,
#   <__main__.Individual at 0x2ccde653370>,
#   <__main__.Individual at 0x2cce00e6850>,
#   <__main__.Individual at 0x2cce00e6d90>],
#  [<__main__.Individual at 0x2ccde653070>,
#   <__main__.Individual at 0x2ccdf8a1b20>,
#   <__main__.Individual at 0x2ccdf8a1eb0>,
#   <__main__.Individual at 0x2cce00e6bb0>,
#   <__main__.Individual at 0x2cce00e6c70>,
#   <__main__.Individual at 0x2cce00d3a90>,
#   <__main__.Individual at 0x2cce00d3fd0>],
#  [<__main__.Individual at 0x2ccde67c970>,
#   <__main__.Individual at 0x2ccdf70c2b0>,
#   <__main__.Individual at 0x2cce00e6a30>],
#  [<__main__.Individual at 0x2ccde3f6e80>,
#   <__main__.Individual at 0x2ccde69f8e0>,
#   <__main__.Individual at 0x2ccdf7201f0>,
#   <__main__.Individual at 0x2ccdf8a1e50>,
#   <__main__.Individual at 0x2cce00e6d30>,
#   <__main__.Individual at 0x2cce00d3af0>],
#  [<__main__.Individual at 0x2ccde653190>,
#   <__main__.Individual at 0x2ccdf720490>,
#   <__main__.Individual at 0x2cce00d3970>],
#  [<__main__.Individual at 0x2ccde653d00>],
#  [<__main__.Individual at 0x2ccdf7203d0>,
#   <__main__.Individual at 0x2cce00e5550>,
#   <__main__.Individual at 0x2cce00d3250>],
#  [<__main__.Individual at 0x2ccdf70cfa0>,
#   <__main__.Individual at 0x2ccdf720430>,
#   <__main__.Individual at 0x2cce00e6910>],
#  [<__main__.Individual at 0x2cce00e50d0>,
#   <__main__.Individual at 0x2cce00e53d0>],
#  [<__main__.Individual at 0x2cce00e6970>,
#   <__main__.Individual at 0x2cce00e54f0>,
#   <__main__.Individual at 0x2cce00d31f0>],
#  [<__main__.Individual at 0x2ccdf720e50>,
#   <__main__.Individual at 0x2cce00cf070>],
#  [<__main__.Individual at 0x2ccdf88b670>],
#  [<__main__.Individual at 0x2ccdf70ca00>,
#   <__main__.Individual at 0x2cce00e5df0>],
#  [],
#  [<__main__.Individual at 0x2ccde6539a0>,
#   <__main__.Individual at 0x2ccdf70c610>,
#   <__main__.Individual at 0x2ccdf70cbe0>],
#  [<__main__.Individual at 0x2ccdf70c1f0>],
#  [<__main__.Individual at 0x2ccdf87af40>],
#  [<__main__.Individual at 0x2ccde6530d0>,
#   <__main__.Individual at 0x2ccde653400>],
#  [<__main__.Individual at 0x2cce00e5d30>],
#  [<__main__.Individual at 0x2cce00e5cd0>],
#  [<__main__.Individual at 0x2ccdf89ca00>,
#   <__main__.Individual at 0x2ccdf87a3d0>,
#   <__main__.Individual at 0x2ccdf70c5b0>,
#   <__main__.Individual at 0x2cce00e5190>],
#  [<__main__.Individual at 0x2ccde4ebfd0>,
#   <__main__.Individual at 0x2ccdf70c4f0>,
#   <__main__.Individual at 0x2cce00e5eb0>,
#   <__main__.Individual at 0x2cce00d3cd0>],
#  [<__main__.Individual at 0x2ccdf720250>],
#  [<__main__.Individual at 0x2ccdf8a1d90>,
#   <__main__.Individual at 0x2cce00d3610>],
#  [<__main__.Individual at 0x2ccdf74e610>,
#   <__main__.Individual at 0x2ccdf8a1bb0>,
#   <__main__.Individual at 0x2cce00e57f0>],
#  [<__main__.Individual at 0x2ccdf70cb80>],
#  [<__main__.Individual at 0x2ccde6536a0>,
#   <__main__.Individual at 0x2ccdf70cac0>,
#   <__main__.Individual at 0x2ccdf70ce20>,
#   <__main__.Individual at 0x2cce00e6370>,
#   <__main__.Individual at 0x2cce00e6e50>],
#  [<__main__.Individual at 0x2ccdf70c6d0>,
#   <__main__.Individual at 0x2cce00e6250>],
#  [],
#  [<__main__.Individual at 0x2ccdf70c880>],
#  [<__main__.Individual at 0x2ccde653490>,
#   <__main__.Individual at 0x2ccde653250>,
#   <__main__.Individual at 0x2ccdf70c940>],
#  [<__main__.Individual at 0x2ccdf88b970>,
#   <__main__.Individual at 0x2cce00e6f10>,
#   <__main__.Individual at 0x2cce00e5430>],
#  [<__main__.Individual at 0x2ccde653bb0>,
#   <__main__.Individual at 0x2ccde4e5130>],
#  [<__main__.Individual at 0x2ccdf6d4070>,
#   <__main__.Individual at 0x2cce00e68b0>],
#  [<__main__.Individual at 0x2ccde653280>,
#   <__main__.Individual at 0x2cce00e5c10>,
#   <__main__.Individual at 0x2cce00d35b0>],
#  [<__main__.Individual at 0x2ccde4e5610>,
#   <__main__.Individual at 0x2ccdf70c760>],
#  [<__main__.Individual at 0x2cce00e65b0>],
#  [<__main__.Individual at 0x2cce00e5d90>],
#  [<__main__.Individual at 0x2ccdf8a1c10>],
#  [<__main__.Individual at 0x2ccdf70c250>],
#  [<__main__.Individual at 0x2ccdf89cb50>],
#  [<__main__.Individual at 0x2ccdf70c3d0>,
#   <__main__.Individual at 0x2cce00e55b0>],
#  [<__main__.Individual at 0x2cce00e6fd0>],
#  [<__main__.Individual at 0x2ccdf6e6640>,
#   <__main__.Individual at 0x2ccdf7204f0>,
#   <__main__.Individual at 0x2cce00e60d0>,
#   <__main__.Individual at 0x2cce00e6310>,
#   <__main__.Individual at 0x2cce00e6550>,
#   <__main__.Individual at 0x2cce00e5250>],
#  [<__main__.Individual at 0x2ccde4e5430>,
#   <__main__.Individual at 0x2ccdf8a1df0>,
#   <__main__.Individual at 0x2cce00d3370>,
#   <__main__.Individual at 0x2cce00d3a30>],
#  [],
#  [<__main__.Individual at 0x2ccde694910>,
#   <__main__.Individual at 0x2ccdf8a18b0>,
#   <__main__.Individual at 0x2cce00e5970>],
#  [<__main__.Individual at 0x2ccdf8a11c0>,
#   <__main__.Individual at 0x2cce00e5bb0>],
#  [<__main__.Individual at 0x2cce00d3490>],
#  [<__main__.Individual at 0x2ccde653a30>,
#   <__main__.Individual at 0x2ccdf6e1520>,
#   <__main__.Individual at 0x2ccde4eb370>,
#   <__main__.Individual at 0x2ccdf70cf40>,
#   <__main__.Individual at 0x2ccdf720550>,
#   <__main__.Individual at 0x2cce00e5a90>],
#  [<__main__.Individual at 0x2ccde653640>,
#   <__main__.Individual at 0x2cce00e5f70>,
#   <__main__.Individual at 0x2cce00d3790>,
#   <__main__.Individual at 0x2cce00cf430>],
#  [<__main__.Individual at 0x2ccde653340>,
#   <__main__.Individual at 0x2ccde653cd0>,
#   <__main__.Individual at 0x2ccde653b50>,
#   <__main__.Individual at 0x2cce00e51f0>],
#  [<__main__.Individual at 0x2ccde4e51f0>,
#   <__main__.Individual at 0x2ccdf8a1f70>],
#  [<__main__.Individual at 0x2cce00e58b0>],
#  [],
#  [<__main__.Individual at 0x2ccde6538b0>,
#   <__main__.Individual at 0x2ccdf720190>,
#   <__main__.Individual at 0x2cce00e6df0>],
#  [<__main__.Individual at 0x2ccdf82f3d0>,
#   <__main__.Individual at 0x2cce00e6cd0>,
#   <__main__.Individual at 0x2cce00d3910>],
#  [<__main__.Individual at 0x2ccde653220>,
#   <__main__.Individual at 0x2ccdf720850>],
#  [<__main__.Individual at 0x2ccde67cb20>,
#   <__main__.Individual at 0x2ccde4eb160>,
#   <__main__.Individual at 0x2cce00e6790>],
#  [<__main__.Individual at 0x2ccde653b20>,
#   <__main__.Individual at 0x2cce00cf310>],
#  [<__main__.Individual at 0x2ccdf74ea00>,
#   <__main__.Individual at 0x2ccde6aa760>],
#  [<__main__.Individual at 0x2ccde6534f0>,
#   <__main__.Individual at 0x2ccdf8a1d30>,
#   <__main__.Individual at 0x2cce00d3c10>],
#  [<__main__.Individual at 0x2cce00e67f0>],
#  [],
#  [<__main__.Individual at 0x2ccdf6d43a0>,
#   <__main__.Individual at 0x2ccdf6ecd00>,
#   <__main__.Individual at 0x2ccdf70c130>,
#   <__main__.Individual at 0x2cce00e6af0>,
#   <__main__.Individual at 0x2cce00e52b0>,
#   <__main__.Individual at 0x2cce00e5730>,
#   <__main__.Individual at 0x2cce00d36d0>,
#   <__main__.Individual at 0x2cce00d3bb0>],
#  [<__main__.Individual at 0x2ccdf70c490>,
#   <__main__.Individual at 0x2cce00cf370>],
#  [<__main__.Individual at 0x2ccde653670>,
#   <__main__.Individual at 0x2cce00e5e50>],
#  [<__main__.Individual at 0x2ccde653ac0>,
#   <__main__.Individual at 0x2ccdf70c0d0>,
#   <__main__.Individual at 0x2cce00e5310>],
#  [<__main__.Individual at 0x2ccdf70c8e0>,
#   <__main__.Individual at 0x2cce00e5790>],
#  [<__main__.Individual at 0x2ccdf70c550>,
#   <__main__.Individual at 0x2cce00cf1f0>],
#  [<__main__.Individual at 0x2ccdf89cc10>,
#   <__main__.Individual at 0x2ccdf720370>],
#  [<__main__.Individual at 0x2ccdf70c190>,
#   <__main__.Individual at 0x2ccdf70ca60>,
#   <__main__.Individual at 0x2ccdf8a1cd0>],
#  [<__main__.Individual at 0x2ccde653310>,
#   <__main__.Individual at 0x2ccdf8a14f0>,
#   <__main__.Individual at 0x2cce00e59d0>,
#   <__main__.Individual at 0x2cce00e5af0>],
#  [<__main__.Individual at 0x2ccdf74e910>,
#   <__main__.Individual at 0x2ccde4e5100>,
#   <__main__.Individual at 0x2ccdf70ce80>,
#   <__main__.Individual at 0x2cce00e5490>,
#   <__main__.Individual at 0x2cce00e5f10>,
#   <__main__.Individual at 0x2cce00d3190>],
#  [<__main__.Individual at 0x2ccdf70cb20>],
#  [],
#  [<__main__.Individual at 0x2ccde653130>,
#   <__main__.Individual at 0x2ccde653550>,
#   <__main__.Individual at 0x2ccde6a4730>,
#   <__main__.Individual at 0x2cce00d30d0>,
#   <__main__.Individual at 0x2cce00d3df0>,
#   <__main__.Individual at 0x2cce00d3e50>],
#  [],
#  [<__main__.Individual at 0x2cce00d34f0>,
#   <__main__.Individual at 0x2cce00d37f0>],
#  [<__main__.Individual at 0x2ccde6a4be0>,
#   <__main__.Individual at 0x2ccdf70cd00>,
#   <__main__.Individual at 0x2cce00e6670>],
#  [<__main__.Individual at 0x2ccde682ca0>,
#   <__main__.Individual at 0x2cce00e69d0>,
#   <__main__.Individual at 0x2cce00d3430>,
#   <__main__.Individual at 0x2cce00d39d0>],
#  [<__main__.Individual at 0x2cce00e62b0>,
#   <__main__.Individual at 0x2cce00e5850>],
#  [<__main__.Individual at 0x2ccdf749e50>,
#   <__main__.Individual at 0x2ccdf70c370>,
#   <__main__.Individual at 0x2cce00e5a30>,
#   <__main__.Individual at 0x2cce00d3c70>],
#  [],
#  [<__main__.Individual at 0x2cce00e6c10>,
#   <__main__.Individual at 0x2cce00d3850>]]
