# %%
install.packages('data/ggridges_0.4.1.tgz', repos=NULL, type="source")

# %%
require('ggridges')

# %%
library(ggplot2)

# %%
ggplot(iris, aes(x = Sepal.Length, y = Species)) + geom_density_ridges()
# Out:
# Picking joint bandwidth of 0.181
# plot without title
