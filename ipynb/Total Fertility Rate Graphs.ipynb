# %%
# %run ../load_magic/storage.py

url = 'blob:https://worldpopulationreview.com/539ddbe9-a3d1-4daa-8832-c13863b68bb3'
s = Storage()
pd.read_csv(url, encoding=s.encoding_type)

# %%
# %run ../load_magic/dataframes.py

url = 'https://worldpopulationreview.com/country-rankings/total-fertility-rate'
dfs_list = get_page_tables(url, verbose=True)

# %%
tfr_df = s.load_csv('total_fertility_rate_by_country2021')

# %%
f = lambda x: 0.837**x
rows_list = []
for x in range(10):
    rows_list.append({'generations': x, 'population': f(x)})

# %%
pd.DataFrame(rows_list).plot('generations', 'population');

# %%
1/.837
# Out:
# 1.1947431302270013
