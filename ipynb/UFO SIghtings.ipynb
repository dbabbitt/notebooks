# %%
# %run ../load_magic/storage.py

s = Storage()
download_url = 'https://data.world/timothyrenner/ufo-sightings/file/nuforc_reports.csv'
nuforc_reports_df = s.load_object('nuforc_reports')
# Out:
# No pickle exists at D:\Documents\GitHub\notebooks\saves\pickle\nuforc_reports.pickle - attempting to load as csv.
# Pickling to D:\Documents\GitHub\notebooks\saves\pickle\nuforc_reports.pickle

# %%
nuforc_reports_df.sample(3).T
# Out:
#                                                             54258  \
# summary                                          Rotating lights.
# city                                                      Keyport
# state                                                          NJ
# date_time                                     2013-12-25T08:30:00
# shape                                                       other
# duration                                                5 minutes
# stats           Occurred : 12/25/2013 08:30  (Entered as : 12/...
# report_link     http://www.nuforc.org/webreports/105/S105622.html
# text            Rotating lights I looked up and a triangle wit...
# posted                                        2014-01-10T00:00:00
# city_latitude                                             40.4405
# city_longitude                                           -74.1754
#
#                                                             21676  \
# ...
