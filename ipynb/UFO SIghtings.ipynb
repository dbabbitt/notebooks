# %%
# %run ../load_magic/storage.py

s = Storage()
download_url = 'https://data.world/timothyrenner/ufo-sightings/file/nuforc_reports.csv'
nuforc_reports_df = s.load_object('nuforc_reports')

# %%
nuforc_reports_df.sample(3).T
# Out:
#                                                             34572  \
# summary         Orange, circular light with steady motion that...
# city                                                     Franklin
# state                                                          PA
# date_time                                     2010-07-04T21:40:00
# shape                                                      circle
# duration                                                5 seconds
# stats           Occurred : 7/4/2010 21:40  (Entered as : 07/04...
# report_link      http://www.nuforc.org/webreports/076/S76420.html
# text            Orange, circular light with steady motion that...
# posted                                        2010-07-19T00:00:00
# city_latitude                                             41.4523
# city_longitude                                           -79.8608
#
#                                                             6407   \
# summary         Burning Object breaks up and smaller objects c...
# city                                                     Folkston
# state                                                          GA
# date_time                                     2020-06-14T05:18:00
# shape                                                      sphere
# duration                                               10 minutes
# stats           Occurred : 6/14/2020 05:18  (Entered as : 06/1...
# report_link     http://www.nuforc.org/webreports/157/S157041.html
# text            Burning Object breaks up and smaller objects c...
# posted                                        2020-06-25T00:00:00
# city_latitude                                             30.8589
# city_longitude                                            -81.972
#
#                                                             45414
# summary         Curved-triangular shape, flying in sky in Lond...
# city                                          London (UK/England)
# state                                                         NaN
# date_time                                     2012-08-19T02:09:00
# shape                                                    triangle
# duration                                            10-13 seconds
# stats           Occurred : 8/19/2012 02:09  (Entered as : 08/1...
# report_link      http://www.nuforc.org/webreports/091/S91918.html
# text            Curved-triangular shape, flying in sky in Lond...
# posted                                        2012-08-19T00:00:00
# city_latitude                                                 NaN
# city_longitude                                                NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-05bc88fbeeeb> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import descartes
# ----> 4 import geopandas as gpd
#       5 from shapely.geometry import Point, Polygon
#       6
#
# D:\Documents\GitHub\rpc\rpc_env\lib\site-packages\geopandas\__init__.py in <module>
# ----> 1 from geopandas._config import options  # noqa
#       2
#       3 from geopandas.geoseries import GeoSeries  # noqa
#       4 from geopandas.geodataframe import GeoDataFrame  # noqa
#       5 from geopandas.array import points_from_xy  # noqa
#
# D:\Documents\GitHub\rpc\rpc_env\lib\site-packages\geopandas\_config.py in <module>
#     124 use_pygeos = Option(
#     125     key="use_pygeos",
# --> 126     default_value=_default_use_pygeos(),
#     127     doc=(
#     128         "Whether to use PyGEOS to speed up spatial operations. The default is True "
#
# D:\Documents\GitHub\rpc\rpc_env\lib\site-packages\geopandas\_config.py in _default_use_pygeos()
#     110
#     111 def _default_use_pygeos():
# --> 112     import geopandas._compat as compat
#     113
#     114     return compat.USE_PYGEOS
#
# D:\Documents\GitHub\rpc\rpc_env\lib\site-packages\geopandas\_compat.py in <module>
#       6
#       7 import pandas as pd
# ----> 8 import pyproj
#       9 import shapely
#      10 import shapely.geos
#
# D:\Documents\GitHub\rpc\rpc_env\lib\site-packages\pyproj\__init__.py in <module>
#      48 import warnings
#      49
# ---> 50 from pyproj import _datadir
#      51 from pyproj._list import (  # noqa: F401
#      52     get_angular_units_map,
#
# ImportError: DLL load failed while importing _datadir: The specified module could not be found.
