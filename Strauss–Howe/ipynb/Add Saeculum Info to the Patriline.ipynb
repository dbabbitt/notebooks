# %%
# %run ../../load_magic/storage.py
# %run ../../load_magic/dataframes.py
# %pprint
# %matplotlib inline
import matplotlib.pyplot as plt

# Use the following only if you are on a high definition device
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

import re
from math import cos, sin, pi
import numpy as np
# %who
# Out:
# DATA_FOLDER: ../data/
# SAVES_FOLDER: ../saves/
# Pretty printing has been turned OFF
# DATA_CSV_FOLDER	 DATA_FOLDER	 ENCODING_TYPE	 SAVES_CSV_FOLDER	 SAVES_FOLDER	 SAVES_PICKLE_FOLDER	 attempt_to_pickle	 cos	 example_iterrows
# get_column_descriptions	 load_csv	 load_dataframes	 load_object	 math	 np	 os	 pd	 pi
# pickle	 plt	 re	 save_dataframes	 sin	 store_objects	 sys

# %%
dataframes_dict = load_dataframes(generations_df='generations_df', patriline_df='patriline_df')
# Out:
# Attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\generations_df.pickle.
# No pickle exists - attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\csv\generations_df.csv.
# Attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\patriline_df.pickle.
# No pickle exists - attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\csv\patriline_df.csv.
# Attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\turnings_df.pickle.
# No pickle exists - attempting to load C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\csv\turnings_df.csv.

# %%
index_name = 'Patriarch Name'
patriline_df = dataframes_dict['patriline_df']
if 'Unnamed: 0' in patriline_df.columns:
    patriline_df = patriline_df.set_index('Unnamed: 0')
elif index_name in patriline_df.columns:
    patriline_df = patriline_df.set_index(index_name)
patriline_df.index.name = index_name

# %%
patriline_df.sample(5).T
# Out:
# Patriarch Name                     William David Babbitt  \
# Year of Birth                                       1791
# Year of Death                                       1861
# Generation Name                               Compromise
# Date of Birth                           October 26, 1791
# Place of Birth   Berkshire, Berkshire, MA, United States
# Birth Longitude                                  42.3931
# Birth Latitude                                  -73.5086
# Date of Death                          May 28, 1861 (69)
# Place of Death   Berkshire, Berkshire, MA, United States
# Death Longitude                                  42.3931
# Death Latitude                                  -73.5086
#
# Patriarch Name                    (No Name), Sr.  \
# Year of Birth                               1518
# Year of Death                               1585
# Generation Name                         Reprisal
# Date of Birth    estimated between 1485 and 1545
# Place of Birth            Unknown Place of Birth
# Birth Longitude                              NaN
# Birth Latitude                               NaN
# Date of Death              Unknown Date of Death
# Place of Death            Unknown Place of Death
# Death Longitude                              NaN
# Death Latitude                               NaN
#
# Patriarch Name                                    Thomas Bobbet  \
# Year of Birth                                              1584
# Year of Death                                              1636
# Generation Name                                   Parliamentary
# Date of Birth                                  October 25, 1584
# Place of Birth   Coney Weston, Suffolk, England, United Kingdom
# Birth Longitude                                         52.3614
# Birth Latitude                                         0.869079
# Date of Death                                         1636 (51)
# Place of Death                 Norfolk, England, United Kingdom
# Death Longitude                                         52.6741
# Death Latitude                                         0.669334
#
# Patriarch Name                                 Elkanah Babbitt, IV  \
# Year of Birth                                                 1737
# Year of Death                                                 1807
# Generation Name                                            Liberty
# Date of Birth                                    December 05, 1737
# Place of Birth          New Milford, New Haven County, Connecticut
# Birth Longitude                                            41.2227
# Birth Latitude                                            -73.0858
# Date of Death                               February 09, 1807 (69)
# Place of Death   Fly Creek, Otsego County, New York, United States
# Death Longitude                                            42.7184
# Death Latitude                                             -74.992
#
# Patriarch Name           David George Babbitt
# Year of Birth                            1961
# Year of Death                             NaN
# Generation Name                          13th
# Date of Birth                       12-Jul-61
# Place of Birth   Flagstaff, AZ, United States
# Birth Longitude                       35.1813
# Birth Latitude                       -111.643
# Date of Death                         Not yet
# Place of Death                   Not anywhere
# Death Longitude                           NaN
# Death Latitude                            NaN

# %%
index_name = 'generation_name'
generations_df = dataframes_dict['generations_df']
if 'Unnamed: 0' in generations_df.columns:
    generations_df = generations_df.set_index('Unnamed: 0')
elif index_name in generations_df.columns:
    generations_df = generations_df.set_index(index_name)
generations_df.index.name = index_name

# %%
generations_df.sample(5).T
# Out:
# generation_name                Parliamentary  \
# childhood_turning_entered                  4
# saeculum_name                    Reformation
# turnings_archetype                    Artist
# generations_archetype               Adaptive
# birth_year_begin                        1566
# birth_year_end                          1587
# childhood_turning_description  Armada Crisis
# turning_year_begin                      1569
# turning_year_end                        1594
#
# generation_name                                                 Lost  \
# childhood_turning_entered                                          2
# saeculum_name                                            Great Power
# turnings_archetype                                             Nomad
# generations_archetype                                       Reactive
# birth_year_begin                                                1883
# birth_year_end                                                  1900
# childhood_turning_description  Missionary Awakening, Progressive era
# turning_year_begin                                              1886
# turning_year_end                                                1908
#
# generation_name                          Arthurian  \
# childhood_turning_entered                        3
# saeculum_name                        Late Medieval
# turnings_archetype                            Hero
# generations_archetype                        Civic
# birth_year_begin                              1433
# birth_year_end                                1460
# childhood_turning_description  Retreat from France
# turning_year_begin                            1435
# turning_year_end                              1459
#
# generation_name                                            Elizabethan  \
# childhood_turning_entered                                            3
# saeculum_name                                              Reformation
# turnings_archetype                                                Hero
# generations_archetype                                            Civic
# birth_year_begin                                                  1541
# birth_year_end                                                    1565
# childhood_turning_description  Marian Restoration, Counter-Reformation
# turning_year_begin                                                1542
# turning_year_end                                                  1569
#
# generation_name                       Puritan
# childhood_turning_entered                   1
# saeculum_name                       New World
# turnings_archetype                    Prophet
# generations_archetype                Idealist
# birth_year_begin                         1588
# birth_year_end                           1617
# childhood_turning_description  Merrie England
# turning_year_begin                       1594
# turning_year_end                         1621

# %%
def f(x):
    generation_name = str(x)
    mask_series = (generations_df.index == generation_name)
    saeculum_name = generations_df[mask_series]['saeculum_name'].tolist()[0]
    
    return saeculum_name

patriline_df['Saeculum Name'] = patriline_df['Generation Name'].map(f)

# %%
columns_list = patriline_df.columns
file_path = os.path.join(DATA_CSV_FOLDER, 'patriline_df.csv')
print('Saving to {}'.format(os.path.abspath(file_path)))
patriline_df[columns_list].to_csv(file_path)
save_dataframes(include_index=True,
                patriline_df=patriline_df[columns_list])
xlsx_folder = os.path.join(DATA_FOLDER, 'xlsx')
os.makedirs(name=xlsx_folder, exist_ok=True)
file_path = os.path.join(xlsx_folder, 'patriline_df.xlsx')
print('Saving to {}'.format(os.path.abspath(file_path)))
patriline_df[columns_list].to_excel(file_path)
# Out:
# Saving to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\data\csv\patriline_df.csv
# Saving to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\csv\patriline_df.csv
# Saving to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\data\xlsx\patriline_df.xlsx

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var body = document.body,
#     attribs = body.attributes;
# var command = "notebook_path = " + "'"+attribs['data-notebook-path'].value+"'";
# kernel.execute(command);

# %%
# %load ../../load_magic/nbviewer.py

from IPython.display import HTML

notebook_viewer_url = 'https://nbviewer.jupyter.org/github/dbabbitt/notebooks/blob/master/'
notebook_viewer_url += '/'.join(notebook_path.split('/')[1:])
html_str = 'Click <a href="{}" target="_blank">here</a> to view notebook in nbviewer.'
HTML(html_str.format(notebook_viewer_url))
# Out:
# Click <a href="https://nbviewer.jupyter.org/github/dbabbitt/notebooks/blob/master/Strauss%E2%80%93Howe/ipynb/Make%20a%20Babbitt%20Spiral-Copy1.ipynb" target="_blank">here</a> to view notebook in nbviewer.
