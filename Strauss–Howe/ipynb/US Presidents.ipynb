# %%
# %run ../../load_magic/storage.py
# %run ../../load_magic/dataframes.py
# %run ../../load_magic/lists.py
from bs4 import BeautifulSoup as bs
import networkx as nx
import re
import urllib.request
# %pprint
# %who
# Out:
# DATA_FOLDER: ../data/
# SAVES_FOLDER: ../saves/
# Pretty printing has been turned OFF
# DATA_CSV_FOLDER	 DATA_FOLDER	 ENCODING_TYPE	 SAVES_CSV_FOLDER	 SAVES_FOLDER	 SAVES_PICKLE_FOLDER	 SequenceMatcher	 attempt_to_pickle	 bs
# check_4_doubles	 check_for_typos	 csv	 encoding	 example_iterrows	 get_column_descriptions	 get_max_rsquared_adj	 get_page_tables	 load_csv
# load_dataframes	 load_object	 math	 nx	 os	 pd	 pickle	 re	 save_dataframes
# similar	 sm	 store_objects	 sys	 time	 urllib

# %%
tables_url = 'http://www.timepage.org/spl/presidents.html'
df_list = get_page_tables(tables_url)
# Out:
# [(1, (13, 5)), (2, (4, 3)), (0, (1, 3)), (3, (1, 3)), (4, (1, 3))]

# %%
df_list[1]
# Out:
#                                          0  \
# 0                                     Eras
# 1          Era of Good Feeling (1788-1821)
# 2     Transcendental Awakening (1822-1837)
# 3     Era of Slavery Expansion (1838-1859)
# 4                Civil War Era (1860-1865)
# 5                   Gilded Age (1866-1885)
# 6         Missionary Awakening (1886-1909)
# 7          WWI/Prohibition Era (1910-1929)
# 8          Depression/WWII Era (1930-1944)
# 9   Era of Super Power America (1945-1965)
# 10              Boom Awakening (1966-1981)
# 11             Information Age (1981-2001)
# 12              Power Down Era? (2002-Now)
#
#                                                     1  \
# 0                                           Idealists
# 1                                                 NaN
# 2                                                 NaN
# 3   1844 - James Polk  1850 - Millard Fillmore  18...
# 4   1860,1864 - Abraham Lincoln  1865 - Andrew Joh...
# 5                                                 NaN
# 6                                                 NaN
# 7   1920 - Warren Harding  1923,1924 - Calvin Cool...
# 8            1932,1936,1940,1944 - Franklin Roosevelt
# 9                                                 NaN
# 10                                                NaN
# 11  1992,1996 - William J. Clinton  2000 - George ...
# 12                              2004 - George W. Bush
#
#                                                     2  \
# 0                                           Reactives
# 1    1788,1792 - George Washington  1796 - John Adams
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1868,1872 - Ulysses Grant  1876 - Rutherford H...
# 6   1888 - Benjamin Harrison  1892 - Grover Cleveland
# 7                                                 NaN
# 8                                                 NaN
# 9   1945,1948 - Harry Truman  1952,1956 - Dwight E...
# 10                                                NaN
# 11                                                NaN
# 12                            2008 -  Barack H. Obama
#
#                                                     3  \
# 0                                              Civics
# 1   1800,1804 - Thomas Jefferson  1808,1812 - Jame...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9     1960 - John Kennedy  1963,1964 - Lyndon Johnson
# 10  1968,1972 - Richard Nixon  1974 - Gerald Ford ...
# 11     1984 - Ronald Reagan  1988 - George H. W. Bush
# 12                                                NaN
#
#                                                     4
# 0                                           Adaptives
# 1                                                 NaN
# 2   1824 - John Q. Adams  1828,1832 - Andrew Jacks...
# 3   1840 - William Harrison  1841 - John Tyler  18...
# 4                                                 NaN
# 5                                                 NaN
# 6   1896,1900 - William McKinley  1901,1904 - Theo...
# 7                          1912,1916 - Woodrow Wilson
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN

# %%
tables_url = 'https://houseofcards.fandom.com/wiki/List_of_Presidents_of_the_United_States_by_date_of_birth'
df_list = get_page_tables(tables_url)
# Out:
# [(1, (19, 10)), (2, (18, 4)), (5, (18, 2)), (3, (13, 6)), (0, (2, 1)), (4, (1, 1))]

# %%
df_list[3]
# Out:
#                                Generation              OB  \
# 0          Liberty Generation (1724–1741)             1 2
# 1       Republican Generation (1742–1766)               3
# 2   Transcendental Generation (1792–1821)              16
# 3       Compromise Generation (1767–1791)             6 7
# 4        Civil War Generation (1822–1842)             NaN
# 5      Progressive Generation (1843–1859)           27 25
# 6       Missionary Generation (1860–1882)              31
# 7      World War I Generation (1883–1900)              32
# 8     World War II Generation (1910–1926)  38 34 40 35 39
# 9           Silent Generation (1927–1945)             NaN
# 10       Baby Boom Generation (1946–1964)     41 42 46 45
# 11               Generation X (1965–1980)             NaN
# 12              Generation AO (2000-2020)             NaN
#
#                                                  Name              OO  \
# 0                        George Washington John Adams             1 2
# 1                                    Thomas Jefferson               3
# 2                                     Abraham Lincoln              16
# 3                    Andrew Jackson John Quincy Adams             7 6
# 4                                                 NaN             NaN
# 5                   Theodore Roosevelt Woodrow Wilson           26 28
# 6                               Franklin D. Roosevelt              32
# 7                                        Harry Truman              33
# 8   John F. Kennedy Lyndon Johnson Jimmy Carter Ro...  35 36 39 40 41
# 9                                                 NaN             NaN
# 10  George W. Bush Bill Clinton Garrett Walker Fra...     43 42 45 46
# 11                                                NaN             NaN
# 12                                                NaN             NaN
#
#                                              Deaths                    Century
# 0                                              None               18th century
# 1                                              None               18th century
# 2                          George Washington (1799)  18th century/19th century
# 3                                              None               18th century
# 4         John Adams (1826) Thomas Jefferson (1826)               19th century
# 5    Andrew Jackson (1845) John Quincy Adams (1848)               19th century
# 6                            Abraham Lincoln (1865)               19th century
# 7                                               NaN               19th century
# 8   Theodore Roosevelt (1919) Woodrow Wilson (1924)               20th century
# 9                      Franklin D. Roosevelt (1945)               20th century
# 10                           John F. Kennedy (1963)               20th century
# 11   Lyndon B. Johnson (1973) Harry S Truman (1972)               20th century
# 12                          Ronald W. Reagan (2004)               21st Century

# %%
tables_url = 'https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States_by_home_state'
df_list = get_page_tables(tables_url)
# Out:
# [(0, (46, 5)), (1, (30, 3)), (2, (18, 3)), (3, (12, 2))]

# %%
from datetime import datetime
from datetime import date

birth_regex = re.compile('([^/†]+/)?([^/†]+)†?')
def f(row_series):
    state_of_birth = row_series['state_of_birth']
    match_obj = birth_regex.search(state_of_birth)
    if match_obj:
        state_of_birth = match_obj.group(2)
    
    return state_of_birth

date_or = '|'.join([date(1900, x+1, 1).strftime('%B') for x in range(12)])
regex_str = r'\((\d+)\w+\) +({}) +(\d+), +(\d+) +– +(({}) +(\d+), +(\d+)|Incumbent)'.format(date_or, date_or)
states_regex = re.compile(regex_str)
def g(row_series):
    in_office = row_series['in_office']
    office_rank = pd.np.nan
    reign_begin = pd.np.nan
    reign_end = pd.np.nan
    match_obj = states_regex.search(in_office)
    if match_obj:
        office_rank = match_obj.group(1)
        in_month = match_obj.group(2)
        in_day = match_obj.group(3)
        in_year = match_obj.group(4)
        reign_begin = datetime.strptime('{} {}, {}'.format(in_month, in_day, in_year), '%B %d, %Y')
        incumbent_str = match_obj.group(5)
        if incumbent_str != 'Incumbent':
            out_month = match_obj.group(6)
            out_day = match_obj.group(7)
            out_year = match_obj.group(8)
            reign_end = datetime.strptime('{} {}, {}'.format(out_month, out_day, out_year), '%B %d, %Y')
    row_series['office_rank'] = office_rank
    row_series['reign_begin'] = reign_begin
    row_series['reign_end'] = reign_end
    
    return row_series

#[fn for fn in dir(pd) if 'x' in fn.lower()]
us_presidents_df = df_list[0].copy().drop(45)
us_presidents_df['Date of birth'] = us_presidents_df['Date of birth'].map(lambda x: datetime.strptime(x, '%B %d, %Y'))
us_presidents_df.columns = ['date_of_birth', 'President', 'birthplace', 'state_of_birth', 'in_office']
us_presidents_df = us_presidents_df.set_index('President')
us_presidents_df['state_of_birth'] = us_presidents_df.apply(f, axis=1)
us_presidents_df['office_rank'] = pd.np.nan
us_presidents_df['reign_begin'] = pd.np.nan
us_presidents_df['reign_end'] = pd.np.nan
us_presidents_df = us_presidents_df.apply(g, axis=1)
columns_list = ['date_of_birth', 'birthplace', 'state_of_birth', 'office_rank', 'reign_begin', 'reign_end']
us_presidents_df = us_presidents_df[columns_list]
store_objects(us_presidents_df=us_presidents_df)
us_presidents_df.sample(5)
# Out:
# Pickling to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\us_presidents_df.pickle
#                     date_of_birth      birthplace state_of_birth office_rank  \
# President
# William H. Taft        1857-09-15      Cincinnati           Ohio          27
# William McKinley       1843-01-29           Niles           Ohio          25
# Warren G. Harding      1865-11-02  Blooming Grove           Ohio          29
# Rutherford B. Hayes    1822-10-04        Delaware           Ohio          19
# Franklin Pierce        1804-11-23    Hillsborough  New Hampshire          14
#
#                     reign_begin  reign_end
# President
# William H. Taft      1909-03-04 1913-03-04
# William McKinley     1897-03-04 1901-09-14
# Warren G. Harding    1921-03-04 1923-08-02
# Rutherford B. Hayes  1877-03-04 1881-03-04
# Franklin Pierce      1853-03-04 1857-03-04

# %%
def g(row_series):
    year_of_birth = row_series['date_of_birth'].year
    mask_series = (generations_df['birth_year_begin'] <= year_of_birth) & (generations_df['birth_year_end'] >= year_of_birth)
    generation_name_list = generations_df[mask_series].index.tolist()
    if len(generation_name_list):
        generation_name = generation_name_list[0]
    else:
        generation_name = pd.np.nan
    
    return generation_name

us_presidents_df['generation_name'] = us_presidents_df.apply(g, axis=1)
store_objects(us_presidents_df=us_presidents_df)
us_presidents_df.sample(5)
# Out:
# Pickling to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\us_presidents_df.pickle
#                        date_of_birth           birthplace  state_of_birth  \
# President
# Herbert Hoover            1874-08-10          West Branch            Iowa
# James K. Polk             1795-11-02            Pineville  North Carolina
# Theodore Roosevelt        1858-10-27        New York City        New York
# Abraham Lincoln           1809-02-12       Sinking Spring        Kentucky
# William Henry Harrison    1773-02-09  Charles City County        Virginia
#
#                        office_rank reign_begin  reign_end generation_name
# President
# Herbert Hoover                  31  1929-03-04 1933-03-04      Missionary
# James K. Polk                   11  1845-03-04 1849-03-04  Transcendental
# Theodore Roosevelt              26  1901-09-14 1909-03-04     Progressive
# Abraham Lincoln                 16  1861-03-04 1865-04-15  Transcendental
# William Henry Harrison           9  1841-03-04 1841-04-04      Compromise

# %%
generations_df = load_object('generations_df')
generations_df.sample(5).T
# Out:
# generation_name                                                Republican  \
# childhood_turning_entered                                               3
# saeculum_name                                               Revolutionary
# turnings_archetype                                                   Hero
# generations_archetype                                               Civic
# birth_year_begin                                                     1742
# birth_year_end                                                       1766
# childhood_turning_description  French and Indian War, British Imperialism
# turning_year_begin                                                   1746
# turning_year_end                                                     1773
#
# generation_name                Parliamentary  \
# childhood_turning_entered                  4
# saeculum_name                    Reformation
# turnings_archetype                    Artist
# generations_archetype               Adaptive
# birth_year_begin                        1566
# birth_year_end                          1587
# childhood_turning_description  Armada Crisis
# turning_year_begin                      1569
# turning_year_end                        1594
#
# generation_name                                                      G.I.  \
# childhood_turning_entered                                               3
# saeculum_name                                                 Great Power
# turnings_archetype                                                   Hero
# generations_archetype                                               Civic
# birth_year_begin                                                     1901
# birth_year_end                                                       1924
# childhood_turning_description  World War I, Prohibition, Roaring Twenties
# turning_year_begin                                                   1908
# turning_year_end                                                     1929
#
# generation_name                      Transcendental                Reprisal
# childhood_turning_entered                         1                       2
# saeculum_name                             Civil War             Reformation
# turnings_archetype                          Prophet                   Nomad
# generations_archetype                      Idealist                Reactive
# birth_year_begin                               1792                    1512
# birth_year_end                                 1821                    1540
# childhood_turning_description  Era of Good Feelings  Protestant Reformation
# turning_year_begin                             1794                    1517
# turning_year_end                               1822                    1542

# %%
patriline_df = load_object('patriline_df')
patriline_df.sample(5).T
# Out:
# patriarch_name               Joseph Robert Babbitt, Sr.  \
# year_of_birth                                      1891
# year_of_death                                      1968
# generation_name                                    Lost
# date_of_birth                              May 04, 1891
# place_of_birth   Flagstaff, Coconino, AZ, United States
# birth_longitude                                 35.1813
# birth_latitude                                 -111.643
# date_of_death                       March 19, 1968 (76)
# place_of_death               Flagstaff, Coconino, AZ, U
# death_longitude                                 35.1813
# death_latitude                                 -111.643
# saeculum_name                               Great Power
# xkcd_color                               xkcd:dandelion
# css4_color                                         gold
# xkcd_text_color                                   black
# css4_text_color                                   black
#
# patriarch_name                                 Elkanah Babbitt, IV  \
# year_of_birth                                                 1737
# year_of_death                                                 1807
# generation_name                                            Liberty
# date_of_birth                                    December 05, 1737
# place_of_birth          New Milford, New Haven County, Connecticut
# birth_longitude                                            41.2227
# birth_latitude                                            -73.0858
# date_of_death                               February 09, 1807 (69)
# place_of_death   Fly Creek, Otsego County, New York, United States
# death_longitude                                            42.7184
# death_latitude                                             -74.992
# saeculum_name                                        Revolutionary
# xkcd_color                                   xkcd:light royal blue
# css4_color                                               royalblue
# xkcd_text_color                                              white
# css4_text_color                                              black
#
# patriarch_name      Stephen Elkanah Babbitt  \
# year_of_birth                          1990
# year_of_death                           NaN
# generation_name                  Millennial
# date_of_birth                      5-Nov-90
# place_of_birth   Beverly, MA, United States
# birth_longitude                     42.5437
# birth_latitude                     -70.8628
# date_of_death                       Not yet
# place_of_death                 Not anywhere
# death_longitude                         NaN
# death_latitude                          NaN
# saeculum_name                    Millennial
# xkcd_color                        xkcd:cyan
# css4_color                             aqua
# xkcd_text_color                       black
# css4_text_color                       black
#
# patriarch_name                David William Babbitt, Jr.  \
# year_of_birth                                       1858
# year_of_death                                       1929
# generation_name                              Progressive
# date_of_birth                               May 14, 1858
# place_of_birth   Cincinnati, Hamilton, OH, United States
# birth_longitude                                  39.1365
# birth_latitude                                  -84.6104
# date_of_death                     November 08, 1929 (71)
# place_of_death    Flagstaff, Coconino, AZ, United States
# death_longitude                                  35.1813
# death_latitude                                  -111.643
# saeculum_name                                  Civil War
# xkcd_color                           xkcd:bright magenta
# css4_color                                       fuchsia
# xkcd_text_color                                    black
# css4_text_color                                    black
#
# patriarch_name                     William David Babbitt
# year_of_birth                                       1791
# year_of_death                                       1861
# generation_name                               Compromise
# date_of_birth                           October 26, 1791
# place_of_birth   Berkshire, Berkshire, MA, United States
# birth_longitude                                  42.3931
# birth_latitude                                  -73.5086
# date_of_death                          May 28, 1861 (69)
# place_of_death   Berkshire, Berkshire, MA, United States
# death_longitude                                  42.3931
# death_latitude                                  -73.5086
# saeculum_name                              Revolutionary
# xkcd_color                             xkcd:primary blue
# css4_color                                          blue
# xkcd_text_color                                    white
# css4_text_color                                    white

# %%
turnings_df = load_object('turnings_df')
turnings_df.sample(5).T
# Out:
# turning_name                                              The Armada Crisis  \
# turning_number                                                            4
# turning_begin_year                                                     1569
# turning_end_year                                                       1594
# saeculum_name                                                         Tudor
# entering_elderhood                                              Reformation
# entering_midlife                                                   Reprisal
# entering_young_adulthood                                       Elizabethans
# entering_childhood                                         Parliamentarians
# turning_notes             The Armada Crisis (Fourth Turning, 1569–1594) ...
#
# turning_name                                      World War I & Prohibition  \
# turning_number                                                            3
# turning_begin_year                                                     1908
# turning_end_year                                                       1929
# saeculum_name                                                   Great Power
# entering_elderhood                                             Progressives
# entering_midlife                                               Missionaries
# entering_young_adulthood                                               Lost
# entering_childhood                                                    G.I.s
# turning_notes             World War I & Prohibition (Third Turning, 1908...
#
# turning_name                                                 Merrie England  \
# turning_number                                                            1
# turning_begin_year                                                     1594
# turning_end_year                                                       1621
# saeculum_name                                                     New World
# entering_elderhood                                                 Reprisal
# entering_midlife                                               Elizabethans
# entering_young_adulthood                                   Parliamentarians
# entering_childhood                                                 Puritans
# turning_notes             Merrie England (First Turning, 1594–1621) was ...
#
# turning_name                                 The Mexican War & Sectionalism  \
# turning_number                                                            3
# turning_begin_year                                                     1844
# turning_end_year                                                       1860
# saeculum_name                                                     Civil War
# entering_elderhood                                             Compromisers
# entering_midlife                                            Transcendentals
# entering_young_adulthood                                             Gilded
# entering_childhood                                             Progressives
# turning_notes             The Mexican War & Sectionalism (Third Turning,...
#
# turning_name                                                  The Civil War
# turning_number                                                            4
# turning_begin_year                                                     1860
# turning_end_year                                                       1865
# saeculum_name                                                     Civil War
# entering_elderhood                                          Transcendentals
# entering_midlife                                                     Gilded
# entering_young_adulthood                                       Progressives
# entering_childhood                                             Missionaries
# turning_notes             The Civil War (Fourth Turning, 1860–1865) bega...

# %%
from datetime import timedelta

def g(row_series):
    reign_begin = row_series['reign_begin']
    reign_end = row_series['reign_end']
    if str(reign_end) == 'NaT':
        reign_end = datetime.now()
    days_delta = int((reign_end - reign_begin).days / 2)
    year_mid = (reign_begin + timedelta(days=days_delta)).year
    mask_series = (turnings_df['turning_begin_year'] <= year_mid) & (turnings_df['turning_end_year'] >= year_mid)
    turning_name_list = turnings_df[mask_series].index.tolist()
    turning_number_list = turnings_df[mask_series]['turning_number'].tolist()
    if len(turning_name_list):
        turning_name = turning_name_list[0]
        turning_number = turning_number_list[0]
    else:
        turning_name = pd.np.nan
        turning_number = pd.np.nan
    row_series['turning_name'] = turning_name
    row_series['turning_number'] = turning_number
    
    return row_series

us_presidents_df = us_presidents_df.apply(g, axis=1)
store_objects(us_presidents_df=us_presidents_df)
us_presidents_df.sample(5)
# Out:
# Pickling to C:\Users\dev\Documents\repositories\notebooks\Strauss–Howe\saves\pickle\us_presidents_df.pickle
#                   date_of_birth           birthplace state_of_birth  \
# President
# Grover Cleveland     1837-03-18             Caldwell     New Jersey
# James Monroe         1758-04-28          Monroe Hall       Virginia
# George Washington    1732-02-22  Westmoreland County       Virginia
# Woodrow Wilson       1856-12-28             Staunton       Virginia
# Millard Fillmore     1800-01-07           Summerhill       New York
#
#                   office_rank reign_begin  reign_end generation_name  \
# President
# Grover Cleveland           22  1885-03-04 1889-03-04          Gilded
# James Monroe                5  1817-03-04 1825-03-04      Republican
# George Washington           1  1789-04-30 1797-03-04         Liberty
# Woodrow Wilson             28  1913-03-04 1921-03-04     Progressive
# Millard Fillmore           13  1850-07-09 1853-03-04  Transcendental
#
#                                      turning_name  turning_number
# President
# Grover Cleveland        The Third Great Awakening               2
# James Monroe             The Era of Good Feelings               1
# George Washington             American Revolution               4
# Woodrow Wilson          World War I & Prohibition               3
# Millard Fillmore   The Mexican War & Sectionalism               3

# %%
def conjunctify_list(noun_list):
    if len(noun_list) > 2:
        list_str = ', and '.join([', '.join(noun_list[:-1])] + [noun_list[-1]])
    elif len(noun_list) == 2:
        list_str = ' and '.join(noun_list)
    elif len(noun_list) == 1:
        list_str = noun_list[0]
    else:
        list_str = ''
    
    return list_str

# %%
mask_series = (us_presidents_df['turning_number'] == 4)
print(conjunctify_list(us_presidents_df[mask_series].index))
us_presidents_df[mask_series]
# Out:
# George Washington, Abraham Lincoln, Herbert Hoover, Franklin D. Roosevelt, Donald Trump, and Barack H. Obama
#                       date_of_birth           birthplace state_of_birth  \
# President
# George Washington        1732-02-22  Westmoreland County       Virginia
# Abraham Lincoln          1809-02-12       Sinking Spring       Kentucky
# Herbert Hoover           1874-08-10          West Branch           Iowa
# Franklin D. Roosevelt    1882-01-30            Hyde Park       New York
# Donald Trump             1946-06-14               Queens       New York
# Barack H. Obama          1961-08-04             Honolulu         Hawaii
#
#                       office_rank reign_begin  reign_end generation_name  \
# President
# George Washington               1  1789-04-30 1797-03-04         Liberty
# Abraham Lincoln                16  1861-03-04 1865-04-15  Transcendental
# Herbert Hoover                 31  1929-03-04 1933-03-04      Missionary
# Franklin D. Roosevelt          32  1933-03-04 1945-04-12      Missionary
# Donald Trump                   45  2017-01-20        NaT       Baby Boom
# Barack H. Obama                44  2009-01-20 2017-01-20            13th
#
#                                               turning_name  turning_number
# President
# George Washington                      American Revolution               4
# Abraham Lincoln                              The Civil War               4
# Herbert Hoover         The Great Depression & World War II               4
# Franklin D. Roosevelt  The Great Depression & World War II               4
# Donald Trump                   The Global Financial Crisis               4
# Barack H. Obama                The Global Financial Crisis               4

# %%
mask_series = (turnings_df['turning_number'] == 4)
turnings_df[mask_series]['turning_number']
# Out:
# turning_name
# The War of the Roses                   4
# The Armada Crisis                      4
# The colonial Glorious Revolution       4
# American Revolution                    4
# The Civil War                          4
# The Great Depression & World War II    4
# The Global Financial Crisis            4
# Name: turning_number, dtype: int64
