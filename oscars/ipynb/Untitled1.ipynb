# %%
# %load ../../load_magic/storage.py

# !mkdir ..\data
# !mkdir ..\data\csv
# !mkdir ..\saves
# !mkdir ..\saves\pickle
# !mkdir ..\saves\csv
import pickle
import pandas as pd
import os
from os.path import join

# Handy list of the different types of encodings
encoding = ['latin1', 'iso8859-1', 'utf-8'][2]

# Change this to your data and saves folders
data_folder = r'../data/'
saves_folder = r'../saves/'

def load_csv(csv_name=None, folder_path=None):
    if folder_path is None:
        csv_folder = data_folder + 'csv/'
    else:
        csv_folder = folder_path + 'csv/'
    if csv_name is None:
        csv_path = max([os.path.join(csv_folder, f) for f in os.listdir(csv_folder)],
                       key=os.path.getmtime)
    else:
        csv_path = csv_folder + csv_name + '.csv'
    data_frame = pd.read_csv(csv_path, encoding=encoding)
    
    return(data_frame)

def load_dataframes(**kwargs):
    frame_dict = {}
    for frame_name in kwargs:
        pickle_path = saves_folder + 'pickle/' + frame_name + '.pickle'
        if not os.path.isfile(pickle_path):
            csv_folder = saves_folder + 'csv/'
            csv_path = csv_folder + frame_name + '.csv'
            if not os.path.isfile(csv_path):
                csv_path = data_folder + 'csv/' + frame_name + '.csv'
                if not os.path.isfile(csv_path):
                    frame_dict[frame_name] = None
                else:
                    frame_dict[frame_name] = load_csv(csv_name=frame_name)
            else:
                frame_dict[frame_name] = load_csv(csv_name=frame_name, folder_path=csv_folder)
        else:
            frame_dict[frame_name] = load_object(frame_name)
    
    return frame_dict

def load_object(obj_name, download_url=None):
    pickle_path = saves_folder + 'pickle/' + obj_name + '.pickle'
    if not os.path.isfile(pickle_path):
        csv_path = data_folder + 'csv/' + obj_name + '.csv'
        if not os.path.isfile(csv_path):
            print('Not in', csv_path)
            object = pd.read_csv(download_url, low_memory=False,
                                 encoding=encoding)
        else:
            object = pd.read_csv(csv_path, low_memory=False,
                                 encoding=encoding)
        if isinstance(object, pd.DataFrame):
            object.to_pickle(pickle_path)
        else:
            with open(pickle_path, 'wb') as handle:
                pickle.dump(object, handle, pickle.HIGHEST_PROTOCOL)
    else:
        try:
            object = pd.read_pickle(pickle_path)
        except:
            with open(pickle_path, 'rb') as handle:
                object = pickle.load(handle)
    
    return(object)

def save_dataframes(include_index=False, **kwargs):
    csv_folder = saves_folder + 'csv/'
    for frame_name in kwargs:
        if isinstance(kwargs[frame_name], pd.DataFrame):
            csv_path = csv_folder + frame_name + '.csv'
            kwargs[frame_name].to_csv(csv_path, sep=',', encoding=encoding,
                                      index=include_index)

# Classes, functions, and methods cannot be pickled
def store_objects(**kwargs):
    for obj_name in kwargs:
        if hasattr(kwargs[obj_name], '__call__'):
            raise RuntimeError('Functions cannot be pickled.')
        obj_path = saves_folder + 'pickle/' + str(obj_name)
        pickle_path = obj_path + '.pickle'
        if isinstance(kwargs[obj_name], pd.DataFrame):
            kwargs[obj_name].to_pickle(pickle_path)
        else:
            with open(pickle_path, 'wb') as handle:
                pickle.dump(kwargs[obj_name], handle, pickle.HIGHEST_PROTOCOL)

def find_file_name(file_name_pattern, root_path=r'C:\\'):
    for dir_path, dir_name_list, file_name_list in os.walk(root_path):
        for file_name in file_name_list:
            if file_name_pattern in file_name:
                file_path = join(dir_path, file_name)
                print(file_path)
# Out:
# A subdirectory or file ..\data already exists.
# A subdirectory or file ..\data\csv already exists.
# A subdirectory or file ..\saves already exists.
# A subdirectory or file ..\saves\pickle already exists.
# A subdirectory or file ..\saves\csv already exists.

# %%
find_file_name('tweet')
# Out:
# C:\\$Recycle.Bin\S-1-5-21-1792459111-2303886026-3530434759-1002\$R8U62Z6\courses-master\algorithms\data\tweets-ukraine.csv.zip
# C:\\Python27\Examples\bokeh\cli\sample_data\create_tweets_file.py
# C:\\Python34\Examples\bokeh\cli\sample_data\create_tweets_file.py
# C:\\Users\Dave\AppData\Local\Google\Chrome\User Data\Default\Extensions\kegphgaihkjoophpabchkmpaknehfamb\3.0.0_0\assets\img\share-tweet-icon.svg
# C:\\Users\Dave\AppData\Local\Google\Chrome\User Data\Default\Local Storage\https_tweetreach.com_0.localstorage
# C:\\Users\Dave\AppData\Local\Google\Chrome\User Data\Default\Local Storage\https_tweetreach.com_0.localstorage-journal
# C:\\Users\Dave\AppData\Local\Google\Chrome\User Data\Profile 1\Extensions\mjcnijlhddpbdemagnpefmlkjdagkogk\0.810_0\a\i\ic_social\16px\retweet.png
# C:\\Users\Dave\Documents\Google Drive\Work\AVI\RFP Spider\phantomjs\examples\tweets.js
# C:\\Users\Dave\Documents\notebooks\courses-master\algorithms\data\tweets-ukraine.csv.zip
# C:\\Users\Dave\Documents\notebooks\courses-master\algorithms\data\tweets.csv.zip
# C:\\Users\Dave\Documents\notebooks\march-madness\Data\tweets.ioo
# C:\\Users\Dave\Documents\notebooks\march-madness\Data\tweets.md
# C:\\Users\Dave\Documents\notebooks\oscars\data\csv\tweets.csv
# C:\\Users\Dave\Documents\notebooks\texas-flooding\tweets.apriori.txt
# C:\\Users\Dave\Documents\Python Scripts\py\tweet_sentiment.JDOGZJ.py
# C:\\Users\Dave\Google Drive\Notebooks\courses-master\algorithms\data\tweets-ukraine.csv.zip
# C:\\Users\Dave\Google Drive\Notebooks\courses-master\algorithms\data (1)\tweets-ukraine.csv.zip
# C:\\Users\Dave\Google Drive\Notebooks\courses-master\algorithms\data (1)\tweets.csv.zip

# %%
tweets_df = load_object('tweets')

# %%
tweets_df.head()
# Out:
#                    ID                  Posted at    Screen name  \
# 0  499350903997337600  2014-08-13 00:25:07 +0000       Gabyhm97
# 1  499350903980564480  2014-08-13 00:25:07 +0000      Putrie_20
# 2  499350908174880768  2014-08-13 00:25:08 +0000  toralesjose96
# 3  499350908179070977  2014-08-13 00:25:08 +0000    xCallMeRedd
# 4  499350908187451396  2014-08-13 00:25:08 +0000     Sharii_Lvp
#
#                                                 Text
# 0  Las cosas hay que arreglarlas, al menos a vos ...
# 1                                       Timbul koler
# 2                                  Cuanto medis vos?
# 3                 My daughter and I just be Chilling
# 4  Ponga Huevo Verde Ponga Huevo Ponga Huevo, Hue...
